# %%
import util.Simulation as Gsim
import util.RotRep as Rot
import numpy as np
import matplotlib.pyplot as plt
from util.config import Config
import os
from util.make_micFile import find_grains
from util.calibration_misc import data_prep, optimize_detector, write_config_file, write_peak_file
import yaml
import h5py
import time

# %%
#######################################################################################
# set misorientation threshold (degrees) to binarize the image for blob finding
blobFindingConf = 1
# set confidence threshold for finding all voxels in a grain through orientation matching
oriMatchingConf = 0.4
#########################################################################################
Cfg = Config('Config_Files/Config_template.yml')
oriMatchingConfArr = np.linspace(0.25, 0.5, num=6)
eulerTolArr = np.linspace(0.25, 2.0, num=11)

for oriMatchingConf in oriMatchingConfArr:
    for eulerTol in eulerTolArr:
        numGrains = find_grains(Cfg, blobFindingConf,
                                oriMatchingConf, eulerTol=eulerTol)
# Out:
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 96
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 80
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 66
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 58
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 57
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 57
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 90
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 79
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 64
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 57
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 56
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 56
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 87
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 77
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 61
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 55
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 82
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 68
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 57
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 50
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 51
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 76
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 62
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 54
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 51
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 49
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 50
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 51
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 51
# -0.556875 -0.360484
# Euler Tolerance applied: 0.25  Number of Grains Found: 73
# -0.556875 -0.360484
# Euler Tolerance applied: 0.425  Number of Grains Found: 59
# -0.556875 -0.360484
# Euler Tolerance applied: 0.6  Number of Grains Found: 53
# -0.556875 -0.360484
# Euler Tolerance applied: 0.7749999999999999  Number of Grains Found: 51
# -0.556875 -0.360484
# Euler Tolerance applied: 0.95  Number of Grains Found: 50
# -0.556875 -0.360484
# Euler Tolerance applied: 1.125  Number of Grains Found: 52
# -0.556875 -0.360484
# Euler Tolerance applied: 1.2999999999999998  Number of Grains Found: 50
# -0.556875 -0.360484
# Euler Tolerance applied: 1.4749999999999999  Number of Grains Found: 48
# -0.556875 -0.360484
# Euler Tolerance applied: 1.65  Number of Grains Found: 49
# -0.556875 -0.360484
# Euler Tolerance applied: 1.825  Number of Grains Found: 50
# -0.556875 -0.360484
# Euler Tolerance applied: 2.0  Number of Grains Found: 50
