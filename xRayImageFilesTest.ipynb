# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from util.config import Config

# %%
fileNumEnd = 1000
Cfg = Config('Config_Files/Config_template.yml')
fn = Cfg.dataFile
for fileNum in range(990, fileNumEnd):
    print (fileNum)
    I = plt.imread(fn+'{0:06d}.tif'.format(fileNum))
    print (fn+'{0:06d}.tif'.format(fileNum))
    imgplot = plt.imshow(I)
    plt.show()
# Out:
# 0
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000000.tif
# 1
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000001.tif
# 2
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000002.tif
# 3
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000003.tif
# 4
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000004.tif
# 5
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000005.tif
# 6
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000006.tif
# 7
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000007.tif
# 8
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000008.tif
# 9
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000009.tif
