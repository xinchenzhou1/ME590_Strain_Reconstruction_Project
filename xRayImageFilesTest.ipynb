# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from util.config import Config

# %%
fileNumEnd = 9855
Cfg = Config('Config_Files/Config_template.yml')
fn = Cfg.dataFile
for fileNum in range(9845, fileNumEnd):
    print (fileNum)
    I = plt.imread(fn+'{0:06d}.tif'.format(fileNum))
    
    print (fn+'{0:06d}.tif'.format(fileNum))
    imgplot = plt.imshow(I)
    plt.show()
# Out:
# 990
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000990.tif
# 991
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000991.tif
# 992
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000992.tif
# 993
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000993.tif
# 994
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000994.tif
# 995
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000995.tif
# 996
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000996.tif
# 997
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000997.tif
# 998
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000998.tif
# 999
# /mnt/data/temp/2013-07-NFStrain/NF/HRM_UnderLoad/Ti7_WithHRM_UnderLoad__000999.tif
